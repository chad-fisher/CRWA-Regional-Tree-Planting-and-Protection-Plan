# %%
import sprf

# %%
help(sprf)
# Out:
# Help on package sprf:
#
# NAME
#     sprf
#
# PACKAGE CONTENTS
#     geographical_random_forest
#     spatial_random_forest
#     tuning
#
# FILE
#     c:\users\chad\appdata\roaming\python\python311\site-packages\sprf\__init__.py

# %%
help(sprf.spatial_random_forest)
# Out:
# Help on module sprf.spatial_random_forest in sprf:
#
# NAME
#     sprf.spatial_random_forest
#
# CLASSES
#     builtins.object
#         SpatialRandomForest
#
#     class SpatialRandomForest(builtins.object)
#      |  SpatialRandomForest(n_estimators: int = 100, sample_mode: str = 'cluster', sample_by: str = 'neighbors', neighbors: int = 500, max_distance: float = 150000, min_points_distance: int = 100, **decision_tree_args)
#      |
#      |  Spatial Random Forest implementation, following the sklearn style
#      |
#      |  Parameters
#      |  ----------
#      |  n_estimators : int, optional
#      |      Number of base estimators (decision trees), by default 20
#      |  sample_mode : str, optional {cluster, random}
#      |      Trees are rooted either in the centers of clusters of the dataset, or in
#      |      random locations, by default "cluster"
#      |  sample_by : str, optional {neighbors, distance}
# ...

# %%
help(sprf.geographical_random_forest)
# Out:
# Help on module sprf.geographical_random_forest in sprf:
#
# NAME
#     sprf.geographical_random_forest
#
# CLASSES
#     builtins.object
#         GeographicalRandomForest
#
#     class GeographicalRandomForest(builtins.object)
#      |  GeographicalRandomForest(sample_by: str = 'neighbors', neighbors: int = 500, max_distance: float = 150000, **random_forest_arguments)
#      |
#      |  Geographical Random Forest according to Georganos et al.
#      |
#      |  Parameters
#      |  ----------
#      |  sample_by : str, optional {neighbors, distance}
#      |      Sampling strategy. The spatial random forest consists of trees that are
#      |      fitted on a spatial subset of samples. These spatial subsets can either
#      |      be sampled by defining a distance-radius, or by specifying a fixed
#      |      number of spatial neighbors. By default "neighbors", see notes below.
#      |  neighbors : int, optional
# ...
